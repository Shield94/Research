# %%
#Important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#plotting with taste
sns.set_theme()
sns.set_context("poster")
plt.style.use('fivethirtyeight')

# %%
#Reading in the sets of data
s12 = pd.read_fwf("s12_o0_2D_gw2.dat")
s40 = pd.read_fwf("s40_o0_2D_gw2.dat")

# %%
s12.head()
# Out:
#     #1 time        2 mass  3 x-momentum  4 y-momentum  5 z-momentum  \
# 0  0.181002  3.711072e+33 -2.162882e+42  1.227700e+33           0.0
# 1  0.181002  3.711072e+33 -2.162882e+42  1.227701e+33           0.0
# 2  0.181002  3.711072e+33 -2.162996e+42  1.229716e+33           0.0
# 3  0.181002  3.711072e+33 -2.163111e+42  1.231601e+33           0.0
# 4  0.181003  3.711072e+33 -2.163226e+42  1.233312e+33           0.0
#
#       6 E_total   7 E_kinetic  8 E_internal      9 E_grav  \
# 0  1.374551e+52  1.424030e+51  1.705478e+52 -3.974552e+52
# 1  1.374551e+52  1.424030e+51  1.705478e+52 -3.974552e+52
# 2  1.374637e+52  1.424181e+51  1.705549e+52 -3.974751e+52
# 3  1.374723e+52  1.424333e+51  1.705620e+52 -3.974951e+52
# 4  1.374809e+52  1.424485e+51  1.705691e+52 -3.975151e+52
#
#    10 explosion energy  ...  52 ddI xx 50<r<150  53 ddI xy=yx 50<r<150  \
# 0                  0.0  ...       -8.359456e+48          -9.690052e+40
# 1                  0.0  ...       -8.359456e+48          -9.690054e+40
# 2                  0.0  ...       -8.359798e+48          -9.685291e+40
# 3                  0.0  ...       -8.360141e+48          -9.680558e+40
# 4                  0.0  ...       -8.360484e+48          -9.675923e+40
#
#   54 ddI yy 50<r<150        55 dI yy 50<r<150 Reisswi 56 A20E2 50<r<150  \
# 0      -5.210751e+45  -5.001942093956047514E+52 -3.27276719404586404...
# 1      -5.210751e+45  -1.130285347418050191E+51 -9.43264074227801720...
# 2      -5.210745e+45  -1.130297130682300221E+51 -9.43294960308557448...
# 3      -5.210739e+45  -1.130308906982285637E+51 -9.43265749197871991...
# 4      -5.210732e+45  -1.130320676311326072E+51 -9.43236532043217207...
#
#    57 dI yy 50<r<150 MOB09  58 ddI xx r>150km  59 ddI xy=yx r>150km  \
# 0            -5.001942e+52      -3.968301e+49         -2.996555e+40
# 1            -1.130285e+51      -3.968301e+49         -2.996553e+40
# 2            -1.130297e+51      -3.968279e+49         -2.996486e+40
# 3            -1.130309e+51      -3.968257e+49         -2.996405e+40
# 4            -1.130321e+51      -3.968234e+49         -2.996315e+40
#
#    60 ddI yy r>150km         61 dI yy r>150km Reisswig 62 A20E2 r>150km  \
# 0      -2.181358e+47  -1.655471737956744556E+52 -2.90673614593842495...
# 1      -2.181358e+47  3.646547176793544985E+49  1.795281352524807602...
# 2      -2.181355e+47  3.650197527399183865E+49  1.795426699960557916...
# 3      -2.181352e+47  3.653847515849593769E+49  1.795376356459783452...
# 4      -2.181349e+47  3.657497142047392132E+49  1.795325942003557827...
#
#    63 dI yy r>150km MOB09
# 0           -1.655472e+52
# 1            3.646547e+49
# 2            3.650198e+49
# 3            3.653848e+49
# 4            3.657497e+49
#
# [5 rows x 61 columns]

# %%
s40.head()
# Out:
#         #1 time        2 mass  3 x-momentum  4 y-momentum  5 z-momentum  \
# 0  0.000000e+00  7.036051e+33 -2.895799e+41  1.934281e+25           0.0
# 1  1.000000e-08  7.036051e+33 -2.895802e+41 -1.934281e+25           0.0
# 2  2.020000e-08  7.036051e+33 -2.895802e+41 -1.934281e+25           0.0
# 3  3.060400e-08  7.036051e+33 -2.895802e+41 -1.934281e+25           0.0
# 4  4.121608e-08  7.036051e+33 -2.895802e+41 -5.802844e+25           0.0
#
#       6 E_total   7 E_kinetic  8 E_internal      9 E_grav  \
# 0 -2.444409e+51  1.171150e+49  6.518029e+51 -1.329731e+52
# 1 -2.444409e+51  1.171151e+49  6.518029e+51 -1.329731e+52
# 2 -2.444409e+51  1.171151e+49  6.518029e+51 -1.329731e+52
# 3 -2.444409e+51  1.171151e+49  6.518029e+51 -1.329731e+52
# 4 -2.444409e+51  1.171151e+49  6.518029e+51 -1.329731e+52
#
#    10 explosion energy  ...  53 ddI xy=yx 50<r<150  54 ddI yy 50<r<150  \
# 0                  0.0  ...           1.190403e+31        8.622487e+42
# 1                  0.0  ...           1.190403e+31        8.622530e+42
# 2                  0.0  ...           1.162673e+31        8.622532e+42
# 3                  0.0  ...           1.134943e+31        8.622534e+42
# 4                  0.0  ...           1.265670e+31        8.622536e+42
#
#          55 dI yy 50<r<150 Reisswi 56 A20E2 50<r<150  57 dI yy 50<r<150 MOB09  \
# 0  2.408200488596564253E+50 -3.136824906005448316...             2.408200e+50
# 1  2.408200969215233222E+50  1.306037129913823955...             2.408201e+50
# 2  2.408201011786559474E+50  1.306037146109369673...             2.408201e+50
# 3  2.408201055209316072E+50  1.306037131988368431...             2.408201e+50
# 4  2.408201099500522119E+50  1.306037117586629717...             2.408201e+50
#
#    58 ddI xx r>150km  59 ddI xy=yx r>150km  60 ddI yy r>150km  \
# 0      -6.590748e+49         -5.192297e+33      -1.416590e+48
# 1      -6.590750e+49          2.076919e+34      -1.416590e+48
# 2      -6.590750e+49         -1.557689e+34      -1.416590e+48
# 3      -6.590750e+49          5.192297e+33      -1.416590e+48
# 4      -6.590750e+49         -1.557689e+34      -1.416590e+48
#
#    61 dI yy r>150km Reisswig  62 A20E2 r>150km  63 dI yy r>150km MOB09
# 0               1.028172e+51      6.971744e+52            1.028172e+51
# 1               1.028172e+51      4.375122e+52            1.028172e+51
# 2               1.028172e+51      4.375122e+52            1.028172e+51
# 3               1.028173e+51      4.375122e+52            1.028173e+51
# 4               1.028173e+51      4.375122e+52            1.028173e+51
#
# [5 rows x 62 columns]

# %%
#values we need to subtract from the time column
s12_time_val = 0.184469701 
s40_time_val = 0.366373606

#Extracting the time values and adjusting them
s12_t = s12["#1 time"] - s12_time_val
s40_t = s40["#1 time"] - s40_time_val

#Solar Mass Conversion for later
solar_mass = 2e33 #g

#Conversion
s12_m = s12["2 mass"]/solar_mass
s40_m = s40["2 mass"]/solar_mass

# %%
#Plotting Neutron Star Mass Vs Time
plt.figure(figsize = (15,7))

#s12_file
plt.subplot(121)
plt.plot(s12_t, s12_m)
plt.title("Neutron Star Mass vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Neutron Star Mass [$M_{\odot}$]")

#s40_file
plt.subplot(122)
plt.plot(s40_t, s40_m)
plt.title("Neutron Star Mass vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Neutron Star Mass [$M_{\odot}$]")

plt.tight_layout()
plt.show()

# %%
#Unit Conversions
solar_radii = 6.957e+10 #cm

#Extracting Correct PNS Radius and adjusting
s12_r = s12["30 correct PNS radius"]/solar_radii
s40_r = s40["30 correct PNS radius"]/solar_radii

# %%
#Plotting Correct PNS Radius Vs Time
plt.figure(figsize = (15,7))

#s12_file
plt.subplot(121)
plt.plot(s12_t, s12_r)
plt.title("Correct PNS Radius vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Correct PNS Radius [$R_{\odot}$]")

#s40_file
plt.subplot(122)
plt.plot(s40_t, s40_r)
plt.title("Correct PNS Radius vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Correct PNS Radius [$R_{\odot}$]")

plt.tight_layout()
plt.show()

# %%
def derivative(func,time):
    derv = []
    t_new = []
    for i in range(0,len(func)-1):
        change_x = time[i+1] - time[i]
        change_y = (func[i+1] - func[i])

        derv.append((change_y)/(change_x))
        
        t_new.append((time[i+1] + time[i])/2)
        
    return [t_new,derv]

# %%
#Define new times and gradients from function.
s12_t_new,s12_derv = derivative(s12_r,s12_t)
s40_t_new,s40_derv = derivative(s40_r,s40_t)
# Out:
# C:\Users\natha\AppData\Local\Temp\ipykernel_14928\521956478.py:8: RuntimeWarning: invalid value encountered in double_scalars
#   derv.append((change_y)/(change_x))

# %%
#Plotting Correct PNS Radius Vs Time
plt.figure(figsize = (15,7))

#s12_file
plt.subplot(121)
plt.plot(s12_t, s12_r)
plt.plot(s12_t_new, s12_derv, lw = .1)
plt.title("Correct PNS Radius vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Correct PNS Radius [$R_{\odot}$]")

#s40_file
plt.subplot(122)
plt.plot(s40_t, s40_r)
plt.plot(s40_t_new, s40_derv, lw= .3)
plt.title("Correct PNS Radius vs Time")
plt.xlabel("Time [sec]")
plt.ylabel("Correct PNS Radius [$R_{\odot}$]")

plt.tight_layout()
plt.show()
